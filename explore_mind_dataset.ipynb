# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
behaviors_columns = ['impression_id', 'user_id', 'time', 'history', 'impression']
beh = pd.read_csv('mind_dataset/train/behaviors.tsv', sep='\t', header=None, 
                  names=behaviors_columns)
beh.head()
# Out:
#    impression_id user_id                   time  \
# 0              1  U13740  11/11/2019 9:05:58 AM
# 1              2  U91836  11/12/2019 6:11:30 PM
# 2              3  U73700  11/14/2019 7:01:48 AM
# 3              4  U34670  11/11/2019 5:28:05 AM
# 4              5   U8125  11/12/2019 4:11:21 PM
#
#                                              history  \
# 0  N55189 N42782 N34694 N45794 N18445 N63302 N104...
# 1  N31739 N6072 N63045 N23979 N35656 N43353 N8129...
# 2  N10732 N25792 N7563 N21087 N41087 N5445 N60384...
# 3  N45729 N2203 N871 N53880 N41375 N43142 N33013 ...
# 4                        N10078 N56514 N14904 N33740
#
#                                           impression
# 0                                  N55689-1 N35729-0
# 1  N20678-0 N39317-0 N58114-0 N20495-0 N42977-0 N...
# 2  N50014-0 N23877-0 N35389-0 N49712-0 N16844-0 N...
# 3                N35729-0 N33632-0 N49685-1 N27581-0
# 4  N39985-0 N36050-0 N16096-0 N8400-1 N22407-0 N6...

# %%
beh['history'] = beh.history.apply(lambda x: [] if isinstance(x, float) else x.split())
beh.head()
# Out:
#    impression_id user_id                   time  \
# 0              1  U13740  11/11/2019 9:05:58 AM
# 1              2  U91836  11/12/2019 6:11:30 PM
# 2              3  U73700  11/14/2019 7:01:48 AM
# 3              4  U34670  11/11/2019 5:28:05 AM
# 4              5   U8125  11/12/2019 4:11:21 PM
#
#                                              history  \
# 0  [N55189, N42782, N34694, N45794, N18445, N6330...
# 1  [N31739, N6072, N63045, N23979, N35656, N43353...
# 2  [N10732, N25792, N7563, N21087, N41087, N5445,...
# 3  [N45729, N2203, N871, N53880, N41375, N43142, ...
# 4                   [N10078, N56514, N14904, N33740]
#
#                                           impression
# 0                                  N55689-1 N35729-0
# 1  N20678-0 N39317-0 N58114-0 N20495-0 N42977-0 N...
# 2  N50014-0 N23877-0 N35389-0 N49712-0 N16844-0 N...
# 3                N35729-0 N33632-0 N49685-1 N27581-0
# 4  N39985-0 N36050-0 N16096-0 N8400-1 N22407-0 N6...

# %%
def get_clicked(impression):
    clicked = []    
    for news in impression.split():
        news_id, state = news.split('-')
        if state == '1':
            clicked.append(news_id)
    return clicked

def get_unclicked(impression):
    unclicked = []    
    for news in impression.split():
        news_id, state = news.split('-')
        if state == '0':
            unclicked.append(news_id)
    return unclicked
        
beh['clicked'] = beh.impression.apply(get_clicked)
beh['unclicked'] = beh.impression.apply(get_unclicked)
beh.head()
# Out:
#    impression_id user_id                   time  \
# 0              1  U13740  11/11/2019 9:05:58 AM
# 1              2  U91836  11/12/2019 6:11:30 PM
# 2              3  U73700  11/14/2019 7:01:48 AM
# 3              4  U34670  11/11/2019 5:28:05 AM
# 4              5   U8125  11/12/2019 4:11:21 PM
#
#                                              history  \
# 0  [N55189, N42782, N34694, N45794, N18445, N6330...
# 1  [N31739, N6072, N63045, N23979, N35656, N43353...
# 2  [N10732, N25792, N7563, N21087, N41087, N5445,...
# 3  [N45729, N2203, N871, N53880, N41375, N43142, ...
# 4                   [N10078, N56514, N14904, N33740]
#
#                                           impression   clicked  \
# 0                                  N55689-1 N35729-0  [N55689]
# 1  N20678-0 N39317-0 N58114-0 N20495-0 N42977-0 N...  [N17059]
# 2  N50014-0 N23877-0 N35389-0 N49712-0 N16844-0 N...  [N23814]
# 3                N35729-0 N33632-0 N49685-1 N27581-0  [N49685]
# ...

# %%
beh[beh['user_id']=='U13740']#[['history', 'clicked', 'unclicked']]['history'][0]
# Out:
#         impression_id user_id                   time  \
# 0                   1  U13740  11/11/2019 9:05:58 AM
# 35262           35263  U13740   11/9/2019 5:59:43 AM
# 154836         154837  U13740  11/13/2019 3:27:40 PM
#
#                                                   history  \
# 0       [N55189, N42782, N34694, N45794, N18445, N6330...
# 35262   [N55189, N42782, N34694, N45794, N18445, N6330...
# 154836  [N55189, N42782, N34694, N45794, N18445, N6330...
#
#                                                impression   clicked  \
# 0                                       N55689-1 N35729-0  [N55689]
# 35262   N20020-0 N3737-0 N43202-0 N18708-0 N30125-0 N3...  [N28910]
# 154836  N13907-0 N8509-0 N47061-0 N51048-0 N22417-0 N3...  [N58133]
#
#                                                 unclicked
# 0                                                [N35729]
# 35262   [N20020, N3737, N43202, N18708, N30125, N349, ...
# 154836  [N13907, N8509, N47061, N51048, N22417, N35273...

# %%
news[news['news_id'].isin(['N55189',
 'N42782',
 'N34694',
 'N45794',
 'N18445',
 'N63302',
 'N10414',
 'N19347',
 'N31801'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 news[news['news_id'].isin(['N55189',
#       2  'N42782',
#       3  'N34694',
#       4  'N45794',
#       5  'N18445',
#       6  'N63302',
#       7  'N10414',
#       8  'N19347',
#       9  'N31801'])]
#
# NameError: name 'news' is not defined

# %%
news_columns = ['news_id', 'category', 
                'sub_category', 'title', 
                'abstract', 'url',
               'title_entities', 'abstract_entities']
news = pd.read_csv('mind_dataset/train/news.tsv', sep='\t', header=None, names=news_columns)
news.head()

# %%
news[~news.title_entities.isna()]['title_entities'][110]

# %%
news.iloc[0][6]

# %%
beh.describe()

# %%
news.title_entities.fillna('[]', inplace=True)
news.abstract_entities.fillna('[]', inplace=True)

# %%
news.category.unique().shape, news.sub_category.unique().shape

# %%
stat = news.groupby('category').count()['news_id']
stat.plot()

# %%
stat.sort_values(ascending=False)
